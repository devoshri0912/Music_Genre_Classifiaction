# %%
import os
import librosa
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from pydub import AudioSegment
from multiprocessing import Pool

# Extracting features
def extract_features(file_path):
    with open(file_path, 'rb') as file:
    #     #X, sample_rate = librosa.load(file, sr=None, mono=True)
    #     X = AudioSegment.from_file(file_path)
    #     sample_rate = X.frame_rate
    #     stft = np.abs(librosa.stft(X))#fourier transformation
    #     mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)#extract multiple features
    #     chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)#tonal content
    #     mel = np.mean(librosa.feature.melspectrogram(y=X, sr=sample_rate).T,axis=0)#spectrography of the ft
    #     contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)#decibel difference between peaks and valleys
    #     tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T,axis=0)#harmonic changes and tones
    # return np.hstack([mfccs,chroma,mel,contrast,tonnetz])

        X = AudioSegment.from_file(file_path)
        sample_rate = X.frame_rate
        data = np.array(X.get_array_of_samples())
        # normalize the data to the range [-1, 1]
        data = data / (2 ** 15)
        # compute the features using librosa
        stft = np.abs(librosa.stft(data))  # Fourier transformation
        mfccs = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate, n_mfcc=40).T, axis=0)  # Extract multiple features
        chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)  # Tonal content
        mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)  # Spectrography of the ft
        contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T, axis=0)  # Decibel difference between peaks and valleys
        #tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(data), sr=sample_rate).T, axis=0)  # Harmonic changes and tones
        return np.hstack([mfccs, chroma, mel, contrast])


# Loading data and extracting features
def load_data(data_path):
    features = []
    labels = []

    # Create a process pool with the specified number of workers
    max_files_per_genre = 25
    # Loop through all subdirectories in data path
    for genre_name in os.listdir(data_path):
        genre_path = os.path.join(data_path, genre_name)
        counter = 0
        # Loop through all subdirectories in genre path
        for artist_name in os.listdir(genre_path):
            artist_path = os.path.join(genre_path, artist_name)
            # Loop through all subdirectories in artist path
            for album_name in os.listdir(artist_path):
                album_path = os.path.join(artist_path, album_name)
                # Loop through all audio files in album path

                for file_name in os.listdir(album_path):
                    if not file_name.endswith('.mp3'):
                        continue
                    file_path = os.path.join(album_path, file_name)
                    print(file_path)
                    counter += 1
                    file_features = extract_features(file_path)
                    features.append(file_features)
                    labels.append(genre_name)
                    if counter >= max_files_per_genre:
                        break
                if counter >= max_files_per_genre:
                    break
            if counter >= max_files_per_genre:
                break
    features = np.array(features)
    labels = np.array(labels)
    return features, labels



# Load data and extract features
data_path = 'drive/MyDrive/training'
features, labels = load_data(data_path)


# X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)
# Out:
# drive/MyDrive/training/pop/the_west_exit/nocturne/3-every_time.mp3
# drive/MyDrive/training/pop/the_kokoon/erase/9-tied.mp3
# drive/MyDrive/training/pop/the_kokoon/erase/6-order.mp3
# drive/MyDrive/training/pop/the_kokoon/erase/7-dawn.mp3
# drive/MyDrive/training/metal/atomic_opera/penguin_dust/6-november.mp3
# drive/MyDrive/training/metal/atomic_opera/penguin_dust/9-watergrave.mp3
# drive/MyDrive/training/metal/atomic_opera/penguin_dust/10-feverdream.mp3
# drive/MyDrive/training/metal/atomic_opera/alpha_&_oranges/8-paper_tiger.mp3
# drive/MyDrive/training/metal/atomic_opera/alpha_&_oranges/10-let_go.mp3
# drive/MyDrive/training/metal/spinecar/passive_aggressive/3-release.mp3
# drive/MyDrive/training/metal/spinecar/autophile/2-stay.mp3
# drive/MyDrive/training/metal/spinecar/autophile/8-push.mp3
# drive/MyDrive/training/metal/spinecar/autophile/7-can't_sleep.mp3
# drive/MyDrive/training/metal/spinecar/up_from_the_mud/6-three.mp3
# drive/MyDrive/training/metal/spinecar/up_from_the_mud/5-kc_rip_off.mp3
# drive/MyDrive/training/metal/utopia_banished/night_of_the_black_wyvern/7-voice_of_disharmony.mp3
# drive/MyDrive/training/metal/utopia_banished/night_of_the_black_wyvern/1-by_mourning.mp3
# drive/MyDrive/training/metal/utopia_banished/night_of_the_black_wyvern/10-forshadowing_the_endless_quest.mp3
# drive/MyDrive/training/metal/skitzo/babblesick/7-heavenly_rain.mp3
# drive/MyDrive/training/metal/skitzo/babblesick/6-last_depression.mp3
# drive/MyDrive/training/metal/skitzo/hellavator_musick/2-angel's_blood.mp3
# drive/MyDrive/training/metal/skitzo/hellavator_musick/7-kill_with_a_vengeance_(live).mp3
# drive/MyDrive/training/metal/seismic_anamoly/afterburner/6-nuclear_blues.mp3
# drive/MyDrive/training/metal/seismic_anamoly/afterburner/7-ten_million_tears.mp3
# drive/MyDrive/training/metal/seismic_anamoly/sweet_rock_candy/7-wreckinball.mp3
# drive/MyDrive/training/metal/seismic_anamoly/sweet_rock_candy/8-refleections.mp3
# drive/MyDrive/training/metal/seismic_anamoly/ramifications/7-serenade_for_samantha.mp3
# drive/MyDrive/training/metal/seismic_anamoly/ramifications/5-code_red_love_is_dead.mp3
# drive/MyDrive/training/metal/seismic_anamoly/dead_man's_hand/3-long_gone.mp3
# drive/MyDrive/training/classical/elizabeth_wolff/moments_musicaux/6-sergei_rachmaninoff_-_6_moment.mp3
# drive/MyDrive/training/classical/elizabeth_wolff/moments_musicaux/2-sergei_rachmaninoff_-_6_moment.mp3
# drive/MyDrive/training/classical/elizabeth_wolff/moments_musicaux/11-moritz_moszkowski_-_4_moments.mp3
# drive/MyDrive/training/classical/elizabeth_wolff/moments_musicaux/7-moritz_moszkowski_-_3_moments.mp3
# drive/MyDrive/training/classical/dufay_collective/cancionero/12-ya_cantan_los_gallos.mp3
# drive/MyDrive/training/classical/dufay_collective/cancionero/7-baxa_de_contrapunto.mp3
# drive/MyDrive/training/classical/dufay_collective/cancionero/22-la_spagna.mp3
# drive/MyDrive/training/classical/dufay_collective/cancionero/17-mi_libertad_en_sosiego.mp3
# drive/MyDrive/training/classical/dufay_collective/cancionero/30-pase_el_agoa_ma_julieta.mp3
# drive/MyDrive/training/classical/dufay_collective/cancionero/8-differencias_sobr'el_canto.mp3
# drive/MyDrive/training/classical/dufay_collective/cancionero/21-que_faray_ie_mal_fortune.mp3
# drive/MyDrive/training/classical/dufay_collective/cancionero/20-fabordon_del_primer_tono.mp3
# drive/MyDrive/training/classical/dufay_collective/a_l'estampida/2-english_danse.mp3
# drive/MyDrive/training/classical/dufay_collective/a_l'estampida/6-estampie_(robertsbridge_codex).mp3
# drive/MyDrive/training/classical/dufay_collective/a_l'estampida/11-salterello.mp3
# drive/MyDrive/training/classical/orinda/airs_de_cour/2-quel_espoir_(pierre_guedron).mp3
# drive/MyDrive/training/classical/orinda/airs_de_cour/17-soit_qu_l'oeil_pourveu_(ode_a_la_reyne)_(jacques_mauduit).mp3
# drive/MyDrive/training/classical/orinda/airs_de_cour/7-amans_qui_vous_plaignes_(pierre_guedron).mp3
# drive/MyDrive/training/classical/orinda/airs_de_cour/9-chaconne_(ennemond_gaultier_le_vieux).mp3
# drive/MyDrive/training/classical/orinda/airs_de_cour/1-ma_belle_si_ton_ame_(gilles_durant_de_la_bergerie).mp3
# drive/MyDrive/training/classical/jacob_heringman_and_catherine/alonso_mudarra_songs_and_solos/32-ysabel_ysabel_perdiste_la_tu.mp3
# drive/MyDrive/training/classical/jacob_heringman_and_catherine/alonso_mudarra_songs_and_solos/11-gallarda.mp3
# drive/MyDrive/training/classical/jacob_heringman_and_catherine/alonso_mudarra_songs_and_solos/20-fantasia_del_primer_tono_(4_co.mp3
# drive/MyDrive/training/classical/jacob_heringman_and_catherine/alonso_mudarra_songs_and_solos/29-recuerde_el_alma_dormida.mp3
# drive/MyDrive/training/classical/jacob_heringman_and_catherine/alonso_mudarra_songs_and_solos/31-fantasia_(del_segundo_tono).mp3
# drive/MyDrive/training/electronic/ivilion/sartinal/7-trestil.mp3
# drive/MyDrive/training/electronic/ivilion/sartinal/1-sartinal_i.mp3
# drive/MyDrive/training/electronic/ivilion/sartinal/3-d_b_l.mp3
# drive/MyDrive/training/electronic/introspekt/ideology/4-tbd.mp3
# drive/MyDrive/training/electronic/introspekt/ideology/3-one_life_to_live.mp3
# drive/MyDrive/training/electronic/introspekt/ideology/1-knucklehead.mp3
# drive/MyDrive/training/electronic/psychetropic/china_radio_sunshine/5-frozen_garden.mp3
# drive/MyDrive/training/electronic/psychetropic/china_radio_sunshine/6-slidewalk.mp3
# drive/MyDrive/training/electronic/psychetropic/china_radio_sunshine/8-dead_slow_day.mp3
# drive/MyDrive/training/electronic/strojovna_07/number_1/15-fajront.mp3
# drive/MyDrive/training/electronic/strojovna_07/number_1/2-selection.mp3
# drive/MyDrive/training/electronic/strojovna_07/number_1/16-ambicious.mp3
# drive/MyDrive/training/electronic/strojovna_07/number_1/8-na_bednicke_stal.mp3
# drive/MyDrive/training/electronic/strojovna_07/mirnix/1-lighting_fly.mp3
# drive/MyDrive/training/electronic/strojovna_07/mirnix/9-taketa.mp3
# drive/MyDrive/training/electronic/strojovna_07/mirnix/5-130.mp3
# drive/MyDrive/training/electronic/strojovna_07/iii/4-loopatchka.mp3
# drive/MyDrive/training/electronic/strojovna_07/iii/11-first_melstorm.mp3
# drive/MyDrive/training/electronic/strojovna_07/iii/9-scava.mp3
# drive/MyDrive/training/electronic/strojovna_07/dirnix/6-palacinka.mp3
# drive/MyDrive/training/electronic/strojovna_07/dirnix/1-dezert.mp3
# drive/MyDrive/training/electronic/strojovna_07/dirnix/9-hukoplex.mp3
# drive/MyDrive/training/electronic/domased/return_back/3-warning_signal.mp3
# drive/MyDrive/training/electronic/domased/return_back/6-bass_vibrations.mp3
# drive/MyDrive/training/electronic/domased/return_back/2-so_easy.mp3
# drive/MyDrive/training/world/kourosh_zolani/peaceful_planet/3-didar.mp3
# drive/MyDrive/training/world/kourosh_zolani/peaceful_planet/10-peaceful_planet.mp3
# drive/MyDrive/training/world/curandero/aras/2-river.mp3
# drive/MyDrive/training/world/curandero/aras/6-aras.mp3
# drive/MyDrive/training/world/curandero/curandero/6-intuitive_plane.mp3
# drive/MyDrive/training/world/curandero/curandero/8-prayer.mp3
# drive/MyDrive/training/world/curandero/curandero/7-ultimos_momentos.mp3
# drive/MyDrive/training/world/tilopa/kyotaku_live/1-yamato_choshi.mp3
# drive/MyDrive/training/world/tilopa/kyotaku_live/5-kyo_rei.mp3
# drive/MyDrive/training/world/tilopa/pictures_of_silence/2-ni.mp3
# drive/MyDrive/training/world/tilopa/pictures_of_silence/5-go.mp3
# drive/MyDrive/training/world/tilopa/turkishauch/1-1x3.mp3
# drive/MyDrive/training/world/tilopa/turkishauch/8-hifumi-chor.mp3
# drive/MyDrive/training/world/tilopa/out_of_the_blue/1-kyo-piano-sus.mp3
# drive/MyDrive/training/world/drevo/christian_themes_in_ukrainian/16-what_wonderful_news.mp3
# drive/MyDrive/training/world/drevo/christian_themes_in_ukrainian/1-for_a_good_day_o_host_to_you.mp3
# drive/MyDrive/training/world/drevo/christian_themes_in_ukrainian/12-our_watcher_show_us_the_way.mp3
# drive/MyDrive/training/world/drevo/christian_themes_in_ukrainian/14-oh_in_jerusalem_there_are_two_monasteries.mp3
# drive/MyDrive/training/world/drevo/christian_themes_in_ukrainian/22-many_years.mp3
# drive/MyDrive/training/world/panacea/songs_and_dance_music_of_europe_east_and_west/1-sandansko_horo.mp3
# drive/MyDrive/training/world/panacea/songs_and_dance_music_of_europe_east_and_west/5-dragaicuta.mp3
# drive/MyDrive/training/world/panacea/songs_and_dance_music_of_europe_east_and_west/14-milk_shake.mp3
# drive/MyDrive/training/world/shiva_in_exile/ethnic/2-breathing.mp3
# drive/MyDrive/training/world/shiva_in_exile/ethnic/9-hollow_earth.mp3
# drive/MyDrive/training/world/shiva_in_exile/ethnic/1-odysseia.mp3
# drive/MyDrive/training/jazz/jag/juke_joint_boogie/3-my_momma_told_me.mp3
# drive/MyDrive/training/jazz/jag/juke_joint_boogie/7-tumbleweed.mp3
# drive/MyDrive/training/jazz/jag/juke_joint_boogie/8-house_rockin.mp3
# drive/MyDrive/training/jazz/jag/cypress_grove_blues/18-slide_boogie.mp3
# drive/MyDrive/training/jazz/jag/cypress_grove_blues/20-greyhound_blues.mp3
# drive/MyDrive/training/jazz/jag/cypress_grove_blues/9-1_carona_no_lime.mp3
# drive/MyDrive/training/jazz/jag/cypress_grove_blues/8-long_road_to_travel.mp3
# drive/MyDrive/training/jazz/jag/cypress_grove_blues/22-unknown_track.mp3
# drive/MyDrive/training/jazz/jag/cypress_grove_blues/19-cause_you_been_messin_'round.mp3
# drive/MyDrive/training/jazz/jag/pretty_girl_blues/14-preachin'_blues.mp3
# drive/MyDrive/training/jazz/jag/pretty_girl_blues/11-jag's_rag.mp3
# drive/MyDrive/training/jazz/jag/pretty_girl_blues/8-down_the_line.mp3
# drive/MyDrive/training/jazz/jag/pretty_girl_blues/12-hopscotch.mp3
# drive/MyDrive/training/jazz/jag/pretty_girl_blues/19-sittin'_under_the_tree.mp3
# drive/MyDrive/training/jazz/thursday_group/uncle_mean/1-like_white_on_rice.mp3
# drive/MyDrive/training/jazz/thursday_group/uncle_mean/2-uncle_mean.mp3
# drive/MyDrive/training/jazz/thursday_group/first_album/6-oaks.mp3
# drive/MyDrive/training/jazz/thursday_group/first_album/7-claytonia.mp3
# drive/MyDrive/training/jazz/scott_hill/steps/9-silk_road.mp3
# drive/MyDrive/training/jazz/scott_hill/steps/1-needs_a_bridge.mp3
# drive/MyDrive/training/jazz/scott_hill/narrow_streets/3-you_think_too_much.mp3
# drive/MyDrive/training/jazz/scott_hill/narrow_streets/5-albuterol.mp3
# drive/MyDrive/training/jazz/drop_trio/big_dipper/10-abbey_rhodes.mp3
# drive/MyDrive/training/jazz/drop_trio/big_dipper/12-slapjack.mp3
# drive/MyDrive/training/jazz/drop_trio/big_dipper/6-invisible_pants.mp3
# drive/MyDrive/training/rock/burnshee_thornside/the_art_of_not_blending_in/13-til_i_met_you.mp3
# drive/MyDrive/training/rock/burnshee_thornside/the_art_of_not_blending_in/5-borderline_(featuring_lilling).mp3
# drive/MyDrive/training/rock/burnshee_thornside/the_art_of_not_blending_in/4-goodbye_on_a_beautiful_day.mp3
# drive/MyDrive/training/rock/burnshee_thornside/the_art_of_not_blending_in/6-love_u_like_a_train.mp3
# drive/MyDrive/training/rock/very_large_array/stuff/4-leisure_waltz.mp3
# drive/MyDrive/training/rock/very_large_array/stuff/2-superdrag.mp3
# drive/MyDrive/training/rock/very_large_array/stuff/10-psychedelic_baby.mp3
# drive/MyDrive/training/rock/tom_paul/i_was_king/11-the_best_in_me.mp3
# drive/MyDrive/training/rock/tom_paul/i_was_king/12-sympathetic_stranger.mp3
# drive/MyDrive/training/rock/tom_paul/i_was_king/9-in_the_morning.mp3
# drive/MyDrive/training/rock/tom_paul/i_was_king/14-i'm_ready_for_you.mp3
# drive/MyDrive/training/rock/tom_paul/there_is_no_map/6-hey_now_babus.mp3
# drive/MyDrive/training/rock/tom_paul/there_is_no_map/12-a_little_part_of_me.mp3
# drive/MyDrive/training/rock/tom_paul/there_is_no_map/11-there_is_no_map.mp3
# drive/MyDrive/training/rock/jackalopes/jacksploitation/4-kentucky_applejack.mp3
# drive/MyDrive/training/rock/jackalopes/jacksploitation/8-cielo_'69.mp3
# drive/MyDrive/training/rock/jackalopes/jacksploitation/12-rotgut.mp3
# drive/MyDrive/training/rock/jackalopes/jacksploitation/9-goddamn_dirty_midgets.mp3
# drive/MyDrive/training/rock/roots_of_rebellion/the_looking_glass/3-shift.mp3
# drive/MyDrive/training/rock/roots_of_rebellion/the_looking_glass/5-legend.mp3
# drive/MyDrive/training/rock/rocket_city_riot/pop_kills/8-she_is_all_i_ever_wanted.mp3
# drive/MyDrive/training/rock/rocket_city_riot/pop_kills/7-mine_tonite.mp3
# drive/MyDrive/training/rock/rocket_city_riot/pop_kills/3-feel_alive.mp3
# drive/MyDrive/training/rock/rocket_city_riot/middle_age_suicide/13-every_day_like_saturday.mp3
# drive/MyDrive/training/rock/rocket_city_riot/middle_age_suicide/2-middle_age_suicide.mp3
# drive/MyDrive/training/punk/pizzle/party_patrol/6-in_my_livid_eyes.mp3
# drive/MyDrive/training/punk/pizzle/party_patrol/11-donkey_punch.mp3
# drive/MyDrive/training/punk/pizzle/party_patrol/4-what's_wrong_with_my_footm.mp3
# drive/MyDrive/training/punk/pizzle/party_patrol/1-party_patrol.mp3
# drive/MyDrive/training/punk/electric_frankenstein/sick_songs/5-born_wild.mp3
# drive/MyDrive/training/punk/electric_frankenstein/sick_songs/7-learn_to_burn.mp3
# drive/MyDrive/training/punk/electric_frankenstein/demo-lition_2004/3-new_world_whore.mp3
# drive/MyDrive/training/punk/electric_frankenstein/demo-lition_2004/6-gone_to_the_other_room.mp3
# drive/MyDrive/training/punk/electric_frankenstein/conquers_the_world!/3-just_like_your_mom.mp3
# drive/MyDrive/training/punk/electric_frankenstein/conquers_the_world!/7-face_at_the_edge_of_the_crowd.mp3
# drive/MyDrive/training/punk/electric_frankenstein/listen_up_baby/6-takin'_it_all.mp3
# drive/MyDrive/training/punk/electric_frankenstein/listen_up_baby/3-hostage_situation.mp3
# drive/MyDrive/training/punk/electric_frankenstein/listen_up_baby/9-perfect_crime.mp3
# drive/MyDrive/training/punk/electric_frankenstein/the_time_is_now!/6-demolition_joyride.mp3
# drive/MyDrive/training/punk/electric_frankenstein/the_time_is_now!/4-right_on_target.mp3
# drive/MyDrive/training/punk/electric_frankenstein/the_time_is_now!/1-teenage_shutdown.mp3

# %%
X_train, X_test, y_train, y_test = train_test_split(features2, labels2, test_size=0.2, random_state=42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
features2 = np.load('drive/MyDrive/ismirdata1.npy')
labels2 = np.load('drive/MyDrive/ismirdata2.npy')

# %%
X_train, X_test, y_train, y_test = train_test_split(features2, labels2, test_size=0.2, random_state=42)

# %% [markdown]
# # New Section

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,precision_score,classification_report


# Create pipeline with preprocessing and SVM model
svm_pipeline = make_pipeline(
    StandardScaler(), # standardize features
    SVC(kernel='rbf', C=10, gamma='scale', random_state=42) # SVM model with RBF kernel
)

# Define hyperparameters to tune with GridSearchCV
param_grid = {
    'svc__C': [0.1, 1, 10], # regularization parameter
    'svc__gamma': [0.001, 0.01, 0.1], # kernel coefficient for 'rbf' kernel
}

# Use GridSearchCV to find best hyperparameters
svm_grid = GridSearchCV(svm_pipeline, param_grid=param_grid, cv=5)
svm_grid.fit(X_train, y_train)

# Fit SVM model with best hyperparameters
svm_model = svm_grid.best_estimator_
svm_model.fit(X_train, y_train)

# Predict labels for test data and evaluate accuracy
y_pred_svm = svm_model.predict(X_test)
svm_accuracy = accuracy_score(y_test, y_pred_svm)
svm_precision = precision_score(y_test,y_pred_svm, average="macro")
print('Accuracy:', svm_accuracy)
print("Precision:", svm_precision)
dt_report = classification_report(y_test, y_pred_svm)
print(dt_report)
# Out:
# Accuracy: 0.8235294117647058
# Accuracy: 0.8235294117647058
# Precision: 0.8238095238095238
#               precision    recall  f1-score   support
#
#    classical       1.00      1.00      1.00         6
#   electronic       0.75      0.50      0.60         6
#         jazz       1.00      1.00      1.00         5
#        metal       0.67      0.57      0.62         7
#         punk       0.60      1.00      0.75         3
#         rock       1.00      1.00      1.00         4
#        world       0.75      1.00      0.86         3
#
#     accuracy                           0.82        34
#    macro avg       0.82      0.87      0.83        34
# weighted avg       0.83      0.82      0.82        34

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MaxAbsScaler, Normalizer, StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import IsolationForest
import numpy as np

# Set a random seed for reproducibility
random_seed = 62
np.random.seed(random_seed)

# Define the scaling methods
scaling_methods = [StandardScaler(), Normalizer()]

# Select the specific iteration with the best accuracy where n_neighbors = 2
best_iteration = {
    'Scaling Methods': ['StandardScaler', 'Normalizer'],
    'Metric': 'euclidean',
    'Weights': 'uniform',
    'n_neighbors': 2
}

# Apply scaling methods one after the other on the entire dataset
X_scaled = np.copy(features2)
for scaler_name in best_iteration['Scaling Methods']:
    scaler = [scaler for scaler in scaling_methods if scaler.__class__.__name__ == scaler_name][0]
    X_scaled = scaler.fit_transform(X_scaled)

# Apply outlier detection using Isolation Forest
outlier_detector = IsolationForest(random_state=random_seed)
outliers = outlier_detector.fit_predict(X_scaled)
X_no_outliers = X_scaled[outliers == 1]
y_no_outliers = labels2[outliers == 1]

# Split the scaled and outlier-filtered dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_no_outliers, y_no_outliers, test_size=0.2, random_state=random_seed)

# Create the KNN classifier with the specified hyperparameters
knn = KNeighborsClassifier(
    n_neighbors=best_iteration['n_neighbors'],
    weights=best_iteration['Weights'],
    metric=best_iteration['Metric']
)

# Train the KNN classifier
knn.fit(X_train, y_train)

# Make predictions on the test set
y_pred_knn = knn.predict(X_test)

# Calculate the accuracy score
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred_knn, average = "macro")

# Print the accuracy
print("Accuracy:", accuracy)
print("Precision:", precision)
dt_report = classification_report(y_test, y_pred_knn)
print(dt_report)
# Out:
# Accuracy: 0.9090909090909091
# Precision: 0.9285714285714286
#               precision    recall  f1-score   support
#
#    classical       0.88      1.00      0.93         7
#   electronic       0.88      0.88      0.88         8
#         jazz       1.00      0.80      0.89         5
#        metal       0.75      1.00      0.86         3
#         punk       1.00      1.00      1.00         1
#         rock       1.00      1.00      1.00         4
#        world       1.00      0.80      0.89         5
#
#     accuracy                           0.91        33
#    macro avg       0.93      0.92      0.92        33
# weighted avg       0.92      0.91      0.91        33

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create and train the logistic regression model
lr = LogisticRegression(max_iter=10000)

# Fit the model to the scaled training data
#whenever you want to train the model you use lr.fit
lr.fit(X_train_scaled, y_train)

# Predict labels for the scaled test data
y_pred_lr = lr.predict(X_test_scaled)

# Calculate the accuracy of the model
lr_accuracy = accuracy_score(y_test, y_pred_lr)

# Perform hyperparameter tuning to find the best parameters
param_grid = {
    'C': [0.1, 1, 10],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga']
}

grid_search = GridSearchCV(estimator=lr, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train_scaled, y_train)

# Get the best hyperparameters and fit the model with them
best_lr = grid_search.best_estimator_
best_accuracy = grid_search.best_score_

# Predict labels for the test data using the best model
y_pred_best_lr = best_lr.predict(X_test_scaled)

# Calculate the accuracy of the best model
best_lr_accuracy = accuracy_score(y_test, y_pred_best_lr)
precision = precision_score(y_test, y_pred_best_lr, average = "macro")


print('Accuracy:', best_lr_accuracy)
print("Precision:", precision)
print(dt_report)
# Out:
# Accuracy: 0.7878787878787878
# Precision: 0.8119047619047618
#               precision    recall  f1-score   support
#
#    classical       0.88      1.00      0.93         7
#   electronic       0.88      0.88      0.88         8
#         jazz       1.00      0.80      0.89         5
#        metal       0.75      1.00      0.86         3
#         punk       1.00      1.00      1.00         1
#         rock       1.00      1.00      1.00         4
#        world       1.00      0.80      0.89         5
#
#     accuracy                           0.91        33
#    macro avg       0.93      0.92      0.92        33
# weighted avg       0.92      0.91      0.91        33

# %%
print('Accuracy:', best_lr_accuracy)
print("Precision:", precision)
# Out:
# Accuracy: 0.8787878787878788
# Precision: 0.9
